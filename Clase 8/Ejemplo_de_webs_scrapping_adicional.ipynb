# %% [markdown]
# <a href="https://colab.research.google.com/github/ccsuehara/python_verano/blob/main/Clase%208/Ejemplo_de_webs_scrapping_adicional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests #html requestor
from bs4 import BeautifulSoup #html parser
import pandas as pd #dataframe manipulator

# %%
headers = {'User-Agent': 'Mozilla/5.0'}
url = 'https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos'

# %%
response = requests.get(url, headers=headers) # we use the headers so that requests imitates the request of a browser
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <!-- Google Tag Manager: Data Layer -->
#   <script>
#    dataLayer = [];
#   </script>
#   <!-- End Google Tag Manager: Data Layer -->
#   <!-- Google Tag Manager: Container code -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PTND4D');
#   </script>
#   <!-- End Google Tag Manager: Container code  -->
#   <meta charset="utf-8"/>
#   <title>
#    Listado de cursos - Facultad de Ciencias Sociales
#   </title>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://facultad.pucp.edu.pe/ciencias-sociales/xmlrpc.php" rel="pingback"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO plugin v16.1.1 - https://yoast.com/wordpress/plugins/seo/ -->
#    <link href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/" rel="canonical">
#     <meta content="es_ES" property="og:locale">
#      <meta content="article" property="og:type"/>
#      <meta content="Listado de cursos - Facultad de Ciencias Sociales" property="og:title"/>
#      <meta content="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/" property="og:url"/>
#      <meta content="Facultad de Ciencias Sociales" property="og:site_name"/>
#      <meta content="2015-05-14T20:43:46+00:00" property="article:modified_time"/>
#      <script class="yoast-schema-graph" type="application/ld+json">
#       {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/#website","url":"https://facultad.pucp.edu.pe/ciencias-sociales/","name":"Facultad de Ciencias Sociales","description":"Facultad de Ciencias Sociales","potentialAction":[{"@type":"SearchAction","target":"https://facultad.pucp.edu.pe/ciencias-sociales/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"es"},{"@type":"WebPage","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/#webpage","url":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/","name":"Listado de cursos - Facultad de Ciencias Sociales","isPartOf":{"@id":"https://facultad.pucp.edu.pe/ciencias-sociales/#website"},"datePublished":"2015-05-14T20:42:49+00:00","dateModified":"2015-05-14T20:43:46+00:00","breadcrumb":{"@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/#breadcrumb"},"inLanguage":"es","potentialAction":[{"@type":"ReadAction","target":["https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/"]}]},{"@type":"BreadcrumbList","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/","url":"https://facultad.pucp.edu.pe/ciencias-sociales/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/","url":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/","name":"Carreras"}},{"@type":"ListItem","position":3,"item":{"@type":"WebPage","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/","url":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/","name":"Antropolog\u00eda"}},{"@type":"ListItem","position":4,"item":{"@type":"WebPage","@id":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/","url":"https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/","name":"Listado de cursos"}}]}]}
#      </script>
#      <!-- / Yoast SEO plugin. -->
#      <link href="//s.w.org" rel="dns-prefetch">
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/feed/" rel="alternate" title="Facultad de Ciencias Sociales » Comentario Listado de cursos del feed" type="application/rss+xml"/>
#       <script type="text/javascript">
#        window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/facultad.pucp.edu.pe\/ciencias-sociales\/wp-includes\/js\/wp-emoji-release.min.js?ver=555fd6d5b8897a90c60d6a1d9ce85b3f"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
#       </script>
#       <style type="text/css">
#        img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#       </style>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-includes/css/dist/block-library/style.min.css?ver=555fd6d5b8897a90c60d6a1d9ce85b3f" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-json/" rel="https://api.w.org/"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-json/wp/v2/pages/1522" rel="alternate" type="application/json"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/?p=1522" rel="shortlink"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ffacultad.pucp.edu.pe%2Fciencias-sociales%2Fcarreras%2Fantropologia%2Flistado-de-cursos%2F" rel="alternate" type="application/json+oembed"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ffacultad.pucp.edu.pe%2Fciencias-sociales%2Fcarreras%2Fantropologia%2Flistado-de-cursos%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#       <script type="text/javascript">
#        (function(url){
# 	if(/(?:Chrome\/26\.0\.1410\.63 Safari\/537\.31|WordfenceTestMonBot)/.test(navigator.userAgent)){ return; }
# 	var addEvent = function(evt, handler) {
# 		if (window.addEventListener) {
# 			document.addEventListener(evt, handler, false);
# 		} else if (window.attachEvent) {
# 			document.attachEvent('on' + evt, handler);
# 		}
# 	};
# 	var removeEvent = function(evt, handler) {
# 		if (window.removeEventListener) {
# 			document.removeEventListener(evt, handler, false);
# 		} else if (window.detachEvent) {
# 			document.detachEvent('on' + evt, handler);
# 		}
# 	};
# 	var evts = 'contextmenu dblclick drag dragend dragenter dragleave dragover dragstart drop keydown keypress keyup mousedown mousemove mouseout mouseover mouseup mousewheel scroll'.split(' ');
# 	var logHuman = function() {
# 		if (window.wfLogHumanRan) { return; }
# 		window.wfLogHumanRan = true;
# 		var wfscr = document.createElement('script');
# 		wfscr.type = 'text/javascript';
# 		wfscr.async = true;
# 		wfscr.src = url + '&r=' + Math.random();
# 		(document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]).appendChild(wfscr);
# 		for (var i = 0; i < evts.length; i++) {
# 			removeEvent(evts[i], logHuman);
# 		}
# 	};
# 	for (var i = 0; i < evts.length; i++) {
# 		addEvent(evts[i], logHuman);
# 	}
# })('//facultad.pucp.edu.pe/ciencias-sociales/?wordfence_lh=1&hid=682ADEEA517A3A39352EB89CA22C6B05');
#       </script>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/css/bootstrap.css" rel="stylesheet"/>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/style.css" rel="stylesheet"/>
#       <!-- COMPLEMENTOS JQUERY-->
#       <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/lib/jquery-2.1.0.min.js">
#       </script>
#       <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/js/jquery.js">
#       </script>
#       <!-- MENU PARA MOVILES -->
#       <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/lib/dropit-ul/jquery.min.js">
#       </script>
#       <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/lib/dropit-ul/dropit.js">
#       </script>
#       <link href="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/lib/dropit-ul/dropit.css" rel="stylesheet" type="text/css">
#        <script type="text/javascript">
#         $(document).ready(function() {
#             $('.menu').dropit();
#         });
#        </script>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/manifest.json" rel="manifest"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/favicon.ico" rel="shortcut icon"/>
#        <link href="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#        <meta content="#ffffff" name="msapplication-TileColor"/>
#        <meta content="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
#        <meta content="#ffffff" name="theme-color"/>
#        <!--
#     .link-descargas2 {
#     padding: 0;
#     display: block;
#     margin-top: 10px;
#     margin-right: 2px;
#     margin-bottom: 5px;
# }
#     -->
#        <style type="text/css">
#         div#container div.listas-internas.lista-noticias a div#intro-multimedia.listado.imagen{
#             float: left;
#             /*margin: 0 20px 5px 0;*/
#             vertical-align: middle;
#         }
#         .select-movil select {
#             display: block;
#             width: 100%;
#             height: 46px;
#             padding: 9px 9px 9px 16px;
#             font-size: 17px;
#             line-height: 1.42857;
#             color: #666;
#             background-color: #FFF;
#             background-image: none;
#             border: 2px solid #D8D8D8;
#             border-radius: 4px;
#             transition: border-color 0.15s ease-in-out 0s,  box-shadow 0.15s ease-in-out 0s;
#         }
#        </style>
#       </link>
#      </link>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PTND4D" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-21752882-2', 'auto');
#   ga('send', 'pageview');
#   </script>
#   <div class="wrapper-barra-sup hidden-xs">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1 barra-sup">
#      <div class="row">
#       <div class="text-right">
#        <a alt="Facebook" class="red-fb" href="https://www.facebook.com/Ciencias.Sociales.PUCP" target="_blank" title="Facebook">
#        </a>
#        <a alt="Contáctenos" class="red-correo" href="https://facultad.pucp.edu.pe/ciencias-sociales/contactenos/" target="_blank" title="Contáctenos">
#        </a>
#        <a alt="Mapa de sitio" class="mapa-link" href="https://facultad.pucp.edu.pe/ciencias-sociales/mapa-de-sitio/" title="Mapa de sitio">
#        </a>
#        <form action="https://facultad.pucp.edu.pe/ciencias-sociales">
#         <div class="form-group">
#          <input class="form-control" id="busca-sitio" name="s" placeholder="Buscar en todo el sitio..." style="display: inline-block;" type="text"/>
#         </div>
#         <input class="busca-enviar" style="display: inline-block;" type="submit" value=""/>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <style>
#    .wrapper-logos{
#                 background: #042354;
#             }
#             .logos a {
#                 background: none;
#             }
#             img.logo-unidad{
#                 margin: 25px 20px 25px 0px;
#                 height: 60px;
#             }
#             @media (max-width: 530px){
#                 img.logo-unidad{
#                     margin: 20px 20px 20px 0px;
#                     height: 48px;
#                     width: auto !important;
#                 }
#             }
#   </style>
#   <div class="wrapper-logos">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1 logos">
#      <div class="row">
#       <div class="col-sm-6 text-right texto-izq col-sm-push-6">
#        <!--<a href="http://www.pucp.edu.pe/" class="logo-pucp">
#                         </a>-->
#       </div>
#       <div class="col-sm-6 col-sm-pull-6">
#        <a href="https://facultad.pucp.edu.pe/ciencias-sociales">
#         <img alt="" class="logo-unidad" src="https://s3.amazonaws.com/files.pucp.edu.pe/pucp-general/img-header/fac_ciencias_sociales.svg"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-logos2 hidden-xs">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1">
#      <div class="row">
#       <a class="logo-unidad2" href="https://facultad.pucp.edu.pe/ciencias-sociales">
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-menu-prin">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1">
#      <div class="navbar navbar-default menu-prin">
#       <div class="navbar-header">
#        <button class="navbar-toggle" data-target=".navbar-responsive-collapse" data-toggle="collapse" type="button">
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#        </button>
#       </div>
#       <div class="navbar-collapse collapse navbar-responsive-collapse">
#        <ul class="nav navbar-nav" id="menu-menu-principal">
#         <li>
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales">
#           Inicio
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-2190" id="menu-item-2190">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/">
#           Facultad
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2191" id="menu-item-2191">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/presentacion/">
#             Presentación
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2192" id="menu-item-2192">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/mision-y-vision/">
#             Misión y Visión
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2193" id="menu-item-2193">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/historia/">
#             Historia
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2194" id="menu-item-2194">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/autoridades/">
#             Autoridades
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4096" id="menu-item-4096">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/personal-academico-y-administrativo/">
#             Personal académico y administrativo
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2195" id="menu-item-2195">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/grados-y-titulos/">
#             Grados y títulos
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3015" id="menu-item-3015">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/acreditacion-de-carreras/">
#             Acreditación de carreras
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2240" id="menu-item-2240">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/infraestructura-y-servicios/">
#             Infraestructura y servicios
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3367" id="menu-item-3367">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/facultad/sistema-de-gestion-de-la-calidad/">
#             Sistema de Gestión de Calidad
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page current-page-ancestor menu-item-has-children menu-item-2196" id="menu-item-2196">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/">
#           Carreras
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page current-page-ancestor menu-item-2197" id="menu-item-2197">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/">
#             Antropología
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2204" id="menu-item-2204">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/">
#             Ciencia Política y Gobierno
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2211" id="menu-item-2211">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/">
#             Economía
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3984" id="menu-item-3984">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/">
#             Finanzas
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4398" id="menu-item-4398">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/">
#             Relaciones Internacionales
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2242" id="menu-item-2242">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/">
#             Sociología
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-2218" id="menu-item-2218">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/admision/">
#           Admisión
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2219" id="menu-item-2219">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/admision/modalidades-para-postulantes/">
#             Modalidades para postulantes
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2220" id="menu-item-2220">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/admision/requisitos-para-alumnos-ee-gg-ll/">
#             Requisitos para alumnos EE.GG.LL
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-2221" id="menu-item-2221">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/">
#           Información Estudiantes / Egresados
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2222" id="menu-item-2222">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/calendario-academico/">
#             Calendario académico
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2223" id="menu-item-2223">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/tramites-de-la-facultad/">
#             Trámites académicos de la Facultad
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2224" id="menu-item-2224">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/tramites-academicos/">
#             Trámites académicos PUCP
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4723" id="menu-item-4723">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/material-informativo/">
#             Material informativo
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4724" id="menu-item-4724">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/buzon-sugerencias-quejas/">
#             Buzón de sugerencias y quejas
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2225" id="menu-item-2225">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/acreditacion-del-idioma/">
#             Acreditación del idioma
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2226" id="menu-item-2226">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/intercambio-estudiantil-pucp/">
#             Intercambio estudiantil PUCP
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2227" id="menu-item-2227">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/convocatorias-de-investigacion-para-estudiantes/">
#             Concursos y premios
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3635" id="menu-item-3635">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/?page_id=3634">
#             Convenios
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-2271" id="menu-item-2271">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/listado-de-profesores/">
#           Docentes
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3644" id="menu-item-3644">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/listado-de-profesores/">
#             Listado de profesores
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3647" id="menu-item-3647">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/listado-de-profesores/grupos-de-investigacion/">
#             Grupos de investigación
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5915" id="menu-item-5915">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/sustentacion-de-tesis/">
#           Tesis sustentadas
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2243" id="menu-item-2243">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/listado-formacion-continua/">
#           Formación continua
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2244" id="menu-item-2244">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/noticias-y-eventos/">
#           Noticias y eventos
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-menu-sec hidden-xs">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1">
#      <div class="navbar navbar-inverse menu-sec menu-secun2">
#       <div class="navbar-collapse collapse">
#        <ul class="nav navbar-nav" id="menu-menu-secundario">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2246" id="menu-item-2246">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/preguntas-frecuentes/">
#           Preguntas frecuentes
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2245" id="menu-item-2245">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/documentos-y-reglamentos/">
#           Documentos y reglamentos
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6560" id="menu-item-6560">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/alerta-ciudadana/">
#           Alerta ciudadana
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4765" id="menu-item-4765">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/sociales-contra-el-acoso/">
#           Sociales contra el acoso
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2247" id="menu-item-2247">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/contactenos/">
#           Contáctanos
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-bc">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1">
#      <div class="bc">
#       <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/">
#        <span>
#         Carreras
#        </span>
#       </a>
#       <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/">
#        <span>
#         Antropología
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-interna">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1 interna">
#      <div class="row">
#       <div class="col-sm-3 menu-lat hidden-xs">
#        <ul class="lista-paginas">
#         <li class="page_item page-item-748 page_item_has_children current_page_ancestor current_page_parent">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/">
#           Antropología
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-1384">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-1388">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-1386">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/plan-de-estudios/">
#             Plan de estudios
#            </a>
#           </li>
#           <li class="page_item page-item-1522 current_page_item">
#            <a aria-current="page" href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/">
#             Listado de cursos
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="page_item page-item-749 page_item_has_children">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/">
#           Ciencia Política y Gobierno
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-1389">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-1393">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-1391">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/plan-de-estudios/">
#             Plan de estudios
#            </a>
#           </li>
#           <li class="page_item page-item-1523">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/ciencia-politica-y-gobierno/listado-de-cursos/">
#             Listado de cursos
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="page_item page-item-750 page_item_has_children">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/">
#           Economía
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-1394">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-1398">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-7296 page_item_has_children">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/nuevo-plan-de-estudios-2/">
#             Nuevo Plan de Estudios y Plan de Transición 2022 – 2023
#            </a>
#            <ul class="children">
#             <li class="page_item page-item-7334">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/nuevo-plan-de-estudios-2/nuevo-plan-de-estudios-de-economia/">
#               Nuevo Plan de Estudios de Economía
#              </a>
#             </li>
#             <li class="page_item page-item-7335">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/nuevo-plan-de-estudios-2/plan-de-transicion-2022-2023/">
#               Plan de Transición 2022 – 2023
#              </a>
#             </li>
#             <li class="page_item page-item-7666">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/nuevo-plan-de-estudios-2/preguntas-frecuentes-sobre-el-nuevo-plan/">
#               Preguntas frecuentes sobre el Nuevo Plan
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="page_item page-item-1396">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/plan-de-estudios/">
#             Plan de Estudios 27
#            </a>
#           </li>
#           <li class="page_item page-item-7314">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/taller-de-trabajos-de-suficiencia-profesional-tsp-para-la-obtencion-del-titulo-de-licenciado-a-en-economia-2021-2/">
#             Taller de Trabajos de Suficiencia Profesional (TSP) para la Obtención del Título de Licenciado/a en Economía 2021-2
#            </a>
#           </li>
#           <li class="page_item page-item-1524">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/listado-de-cursos/">
#             Listado de cursos
#            </a>
#           </li>
#           <li class="page_item page-item-3005 page_item_has_children">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/acreditacion-internacional/">
#             Acreditación internacional
#            </a>
#            <ul class="children">
#             <li class="page_item page-item-3008">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/acreditacion-internacional/proceso/">
#               Proceso de acreditación
#              </a>
#             </li>
#             <li class="page_item page-item-3042">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/acreditacion-internacional/comite-acreditacion/">
#               Comité de Acreditación
#              </a>
#             </li>
#             <li class="page_item page-item-3006">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/economia/acreditacion-internacional/criterios/">
#               Criterios de evaluación
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li class="page_item page-item-3981 page_item_has_children">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/">
#           Finanzas
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-3982">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-3983">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-3985">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/plan-de-estudios/">
#             Plan de estudios
#            </a>
#           </li>
#           <li class="page_item page-item-5073">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/finanzas/listado-de-cursos/">
#             Listado de Cursos
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="page_item page-item-4381 page_item_has_children">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/">
#           Relaciones Internacionales
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-4382">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-4393">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-4394">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/plan-de-estudios/">
#             Plan de estudios
#            </a>
#           </li>
#           <li class="page_item page-item-4395">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/relaciones-internacionales/listado-de-cursos/">
#             Listado de cursos
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="page_item page-item-751 page_item_has_children">
#          <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/">
#           Sociología
#          </a>
#          <ul class="children">
#           <li class="page_item page-item-1399">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/sobre-la-carrera/">
#             Sobre la carrera
#            </a>
#           </li>
#           <li class="page_item page-item-1403">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/campo-laboral/">
#             Campo laboral
#            </a>
#           </li>
#           <li class="page_item page-item-1401">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/plan-de-estudios/">
#             Plan de estudios
#            </a>
#           </li>
#           <li class="page_item page-item-1525">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/listado-de-cursos/">
#             Listado de cursos
#            </a>
#           </li>
#           <li class="page_item page-item-3009 page_item_has_children">
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/acreditacion-internacional/">
#             Acreditación internacional
#            </a>
#            <ul class="children">
#             <li class="page_item page-item-3012">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/acreditacion-internacional/proceso/">
#               Proceso de acreditación
#              </a>
#             </li>
#             <li class="page_item page-item-3041">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/acreditacion-internacional/comite-acreditacion/">
#               Comité de Acreditación
#              </a>
#             </li>
#             <li class="page_item page-item-3013">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/acreditacion-internacional/criterios-evaluacion/">
#               Criterios de evaluación
#              </a>
#             </li>
#             <li class="page_item page-item-3014">
#              <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/sociologia/acreditacion-internacional/beneficios/">
#               Beneficios de la acreditación
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-9 cuerpo">
#        <div class="select-movil visible-xs-block">
#         <ul class="menu dropit" id="menu1">
#          <li class="dropit-trigger">
#           <a class="btn-dropit" href="#">
#            Listado de cursos
#           </a>
#           <ul class="dropit-submenu">
#            <li class="page_item page-item-1384">
#             <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/sobre-la-carrera/">
#              Sobre la carrera
#             </a>
#            </li>
#            <li class="page_item page-item-1388">
#             <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/campo-laboral/">
#              Campo laboral
#             </a>
#            </li>
#            <li class="page_item page-item-1386">
#             <a href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/plan-de-estudios/">
#              Plan de estudios
#             </a>
#            </li>
#            <li class="page_item page-item-1522 current_page_item">
#             <a aria-current="page" href="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/">
#              Listado de cursos
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#        <h1>
#         Listado de cursos
#        </h1>
#        <div class="formato tamano-normal">
#         <div class="lista-cursos-box">
#          <div class="lista-input">
#           <div class="form-group container-fluid">
#            <label class="col-sm-3 busca-titulo" for="select">
#             Buscar por:
#            </label>
#            <form action="https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/">
#             <div class="col-sm-9 busca-campos">
#              <div class="input-group">
#               <input class="form-control busca-caja" name="buscar" placeholder="Nombre del curso o clave" type="text"/>
#               <span class="input-group-btn">
#                <button class="btn btn-default" type="submit">
#                 <i class="glyphicon glyphicon-search">
#                 </i>
#                </button>
#               </span>
#              </div>
#             </div>
#            </form>
#           </div>
#           <div class="form-group container-fluid">
#            <label class="col-sm-3 busca-titulo" for="select">
#             Ver por nivel:
#            </label>
#            <div class="col-sm-9 busca-campos">
#             <select class="form-control" id="select" name="nivel">
#              <option>
#               Escoge
#              </option>
#              <option value="5">
#               5
#              </option>
#              <option value="6">
#               6
#              </option>
#              <option value="7">
#               7
#              </option>
#              <option value="8">
#               8
#              </option>
#              <option value="9">
#               9
#              </option>
#              <option value="10">
#               10
#              </option>
#              <option value="11">
#               11
#              </option>
#             </select>
#            </div>
#           </div>
#          </div>
#          <div class="checks-lista">
#           <div class="checks-item checkbox container-fluid">
#            <h3>
#             Tipo de Curso
#            </h3>
#            <div class="ancho-filtro-cuerpo">
#             <label>
#              <input name="fuentes" type="checkbox" value="Electivo"/>
#              Electivo
#             </label>
#            </div>
#            <div class="ancho-filtro-cuerpo">
#             <label>
#              <input name="fuentes" type="checkbox" value="Obligatorio"/>
#              Obligatorio
#             </label>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="barra-inf">
#         </div>
#         <div class="wrapper-listas2 borde-lista container-fluid">
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/seminario-interdisciplinario-temas-ciencias-sociales-2/?Carrera=antropologia">
#             Seminario interdisciplinario de temas en ciencias sociales 2
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: V
#             </span>
#             <span>
#              Créditos: 3
#             </span>
#             <span>
#              Clave: 1INT34
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Electivo
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Curso interdisciplinario de contenido variable sobre temas analizados y discutidos por las Ciencias Sociales. Se ofrece a los y las estudiantes  perspectivas analíticas de las distintas especialidades de las ciencias sociales a modo de conocer las distintas aproximaciones y debates en torno a un mismo fenómeno…
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/seminario-interdisciplinario-temas-ciencias-sociales-1/?Carrera=antropologia">
#             Seminario interdisciplinario de temas en ciencias sociales 1
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: V
#             </span>
#             <span>
#              Créditos: 3
#             </span>
# ...
#             <span>
#              Tipo de curso: Electivo
#             </span>
#             <span>
#              Área: Estudios Andinos
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Curso de contenido variable; sobre un tema investigado por un profesor de la Especialidad y que tiene una relevancia particular.
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-de-antropologia-amazonica/?Carrera=antropologia">
#             Temas de antropología amazónica
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: V
#             </span>
#             <span>
#              Créditos: 3
#             </span>
#             <span>
#              Clave: ANT 281
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Electivo
#             </span>
#             <span>
#              Área: Estudios Andinos
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Curso de contenido variable; sobre un tema investigado por un profesor de la Especialidad y que tiene una relevancia particular.
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-en-metodologia-de-la-investigacion/?Carrera=antropologia">
#             Temas en metodología de la investigación
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: V
#             </span>
#             <span>
#              Créditos: 3
#             </span>
#             <span>
#              Clave: ANT 290
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Electivo
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Curso de contenido variable; sobre un tema investigado por un profesor de la Especialidad y que tiene una relevancia particular.
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/metodos-y-tecnicas-de-investigacion-antropologica-1/?Carrera=antropologia">
#             Métodos y Técnicas de Investigación Antropológica 1
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: VIII
#             </span>
#             <span>
#              Créditos: 4
#             </span>
#             <span>
#              Clave: ANT 293
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Obligatorio
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Principales debates epistemológicos en torno al método antropológico. La observación participante, el método comparativo. Diseño de un proyecto de investigación. Procesos de conceptualización y operacionalización de hipótesis y variables. Planteamiento de la investigación.
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/etnografia-amazonica/?Carrera=antropologia">
#             Etnografía Amazónica
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: V
#             </span>
#             <span>
#              Créditos: 4
#             </span>
#             <span>
#              Clave: ANT 296
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Obligatorio
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             La Amazonía como área cultural. Las culturas nativas. Métodos de aproximación y líneas de estudio. Ecología, economía y organización social. La colonización, proyectos de desarrollo y su impacto en los grupos nativos. Políticas en América Latina sobre minorías étnicas de la Amazonia. Las comunidades nativas…
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/metodos-y-tecnicas-de-investigacion-antropologica-2/?Carrera=antropologia">
#             Métodos y Técnicas de Investigación Antropológica 2
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: IX
#             </span>
#             <span>
#              Créditos: 4
#             </span>
#             <span>
#              Clave: ANT 297
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Obligatorio
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Delimitación de la población a estudiar. Las técnicas clásicas en antropología; la etnografía. Las técnicas cualitativas: entrevista, historia de vida, historia oral.
#            </p>
#           </p>
#          </div>
#          <div class="col-sm-12 listas-internas">
#           <h2>
#            <a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/metodos-y-tecnicas-de-investigacion-antropologica-3/?Carrera=antropologia">
#             Métodos y Técnicas de Investigación Antropológica 3
#            </a>
#           </h2>
#           <div class="lista-cursos-detalles">
#            <div class="cursos-datos">
#             <span>
#              Nivel: X
#             </span>
#             <span>
#              Créditos: 4
#             </span>
#             <span>
#              Clave: ANT 295
#             </span>
#            </div>
#            <div class="cursos-detalles">
#             <span>
#              Tipo de curso: Obligatorio
#             </span>
#            </div>
#           </div>
#           <p>
#            <p>
#             Métodos de análisis de datos. El problema de la representatividad y la generalización de datos cualitativos. Los métodos de análisis cualitativo (análisis de contenido, análisis estructural, etc.) Codificación de datos. Análisis computarizado de datos.
#            </p>
#           </p>
#          </div>
#         </div>
#         <div class="container-fluid ancho-resultados">
#          <div class="resultados-ver-mas btn btn-info col-xs-12" id="ver_mas">
#           Ver más
#          </div>
#         </div>
#        </div>
#        <script type="text/javascript">
#         $(document).ready(function(){
#                                 var nummax  = 8;
#                                 var $Items = '.borde-lista div.col-sm-12.listas-internas';
#                                 var $Total = $($Items).length;
#                                 $($Items).attr('style','display:none;');
#                                 $($Items+":lt(" + nummax + ")").fadeIn("slow");
#                                 $("#ver_mas").click(function(){
#                                     nummax = nummax + 8;
#                                     $($Items+":lt(" + nummax + ")").fadeIn("slow");
#                                     if(nummax>=$Total){
#                                         $('#ver_mas').fadeOut("fast");
#                                     }
#                                 });
#                                 if(nummax>=$Total) {
#                                     $('#ver_mas').fadeOut("fast");
#                                 }
#
#
#                                 $("#select").change(function(){
#                                     $Campos = $(this).val();
#                                     window.document.location.href='https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/?nivel='+$Campos;
#                                 });
#                                 $("input[name=fuentes]").change(function () {
#                                     var tipoDocum = [];
#                                     $("input[name=fuentes]:checked").each(function(){
#                                         tipoDocum.push( $(this).val() );
#                                     });
#                                     GetTipoFuente  = tipoDocum.join(",");
#                                     window.document.location.href='https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/?nivel=&tipocurso='+GetTipoFuente;
#                                 });
#                             });
#        </script>
#        <style type="text/css">
#         a.addthis_button img{ width:0px; }
# 									a.compartir-email.addthis_button_email.at300b span.at-icon-wrapper{
# 									  height:0px !important;
# 									  width:0px !important;
# 									}
#        </style>
#        <div class="container-fluid share hidden-xs">
#         <div class="col-sm-7 compartir">
#          <span class="txt">
#           Compartir vía:
#          </span>
#          <a class="compartir-facebook" href="http://www.facebook.com/sharer.php?u=https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/" target="_blank" title="Facebook">
#          </a>
#          <a class="compartir-linkedin" href="http://www.linkedin.com/cws/share?url=https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/" target="_blank" title="LinkedIn">
#          </a>
#          <a class="compartir-otrasredes addthis_button" target="_blank" title="Más...">
#          </a>
#         </div>
#         <div class="col-sm-5 compartir text-right">
#          <span class="txt">
#           Enviar a:
#          </span>
#          <a class="compartir-imprimir" onclick="window.print();" title="Imprimir">
#          </a>
#          <a class="compartir-pdf" href="http://savepageaspdf.pdfonline.com/pdfonline/pdfonline.asp?cURL=https://facultad.pucp.edu.pe/ciencias-sociales/carreras/antropologia/listado-de-cursos/&amp;author_id=f30e7a76-0734-483d-9307-3858b31a968e" title="PDF">
#          </a>
#          <a "="" antropologia="" carreras="" ciencias-sociales="" class="compartir-email addthis_button_email at300b" facultad.pucp.edu.pe="" href="mailto:?subject=&amp;body=" https:="" listado-de-cursos="" title="Email">
#          </a>
#         </div>
#         <div class="clear cero">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="wrapper-footer">
#    <div class="container">
#     <div class="col-lg-10 col-lg-offset-1 footer">
#      <div class="row">
#       <div class="col-sm-4 footer-modu">
#        <div class="footer-facebook">
#         <img alt="" src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/images/facebook-footer.jpg"/>
#        </div>
#        <h3>
#         Enlaces de Interés
#        </h3>
#        <ul>
#         <li>
#          <a href="https://cisepa.pucp.edu.pe/" target="_blank" title="CISEPA">
#           CISEPA
#          </a>
#         </li>
#         <li>
#          <a href="http://departamento.pucp.edu.pe/ciencias-sociales/" target="_blank" title="Departamento de Ciencias Sociales">
#           Departamento de Ciencias Sociales
#          </a>
#         </li>
#         <li>
#          <a href="http://departamento.pucp.edu.pe/economia/" target="_blank" title="Departamento de Economía">
#           Departamento de Economía
#          </a>
#         </li>
#         <li>
#          <a href="http://facultad.pucp.edu.pe/generales-letras/" target="_blank" title="Facultad de Estudios Generales Letras">
#           Facultad de Estudios Generales Letras
#          </a>
#         </li>
#         <li>
#          <a href="http://biblioteca.pucp.edu.pe/" target="_blank" title="Sistema de Bibliotecas PUCP">
#           Sistema de Bibliotecas PUCP
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-4 footer-modu">
#        <h3>
#         Servicios PUCP
#        </h3>
#        <ul>
#         <li>
#          <a href="https://campusvirtual.pucp.edu.pe/" target="_blank">
#           Campus Virtual
#          </a>
#         </li>
#         <li>
#          <a href="https://intranet.pucp.edu.pe" target="_blank">
#           Correo PUCP
#          </a>
#         </li>
#         <li>
#          <a href="https://biblioteca.pucp.edu.pe/" target="_blank">
#           Biblioteca
#          </a>
#         </li>
#         <li>
#          <a href="https://agenda.pucp.edu.pe/" target="_blank">
#           Agenda PUCP
#          </a>
#         </li>
#         <li>
#          <a href="https://serviciodesalud.pucp.edu.pe/" target="_blank">
#           Servicio de Salud
#          </a>
#         </li>
#        </ul>
#        <h3>
#         Redes Sociales PUCP
#        </h3>
#        <a class="footer-fb" href="https://www.facebook.com/pucp/" target="_blank">
#        </a>
#        <a class="footer-tw" href="https://twitter.com/pucp/" target="_blank">
#        </a>
#        <a class="footer-yt" href="https://youtube.com/pucp/" target="_blank">
#        </a>
#       </div>
#       <div class="col-sm-4 footer-modu">
#        <div class="footer-bloque">
#         <h3>
#          Ubicación
#         </h3>
#         <p>
#          Av. Universitaria 1801, San Miguel, 15088, Lima - Perú
#         </p>
#         <a class="footer-gm" href="https://www.google.com.pe/maps/place/Pontificia+Universidad+Cat%C3%B3lica+del+Per%C3%BA/@-12.069512,-77.0815479,17z/data=!3m1!4b1!4m5!3m4!1s0x9105c912d40840a5:0xd7a0bfb797e5862e!8m2!3d-12.069512!4d-77.0793592" target="_blank">
#          Ver ubicación en Google Maps
#         </a>
#        </div>
#        <h3>
#         Contacto
#        </h3>
#        <p>
#         Teléfono: (+511) 626-2000 anexo 5386 / 5387
#        </p>
#        <a class="footer-ct" href="mailto:mesadepartessociales@pucp.edu.pe" target="_blank">
#         mesadepartessociales@pucp.edu.pe
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container borde-footer">
#     <div class="col-lg-12 footer">
#      <div class="col-sm-12 footer-bottom">
#       <p>
#        Pontificia Universidad Católica del Perú | Av. Universitaria 1801, San Miguel, 15088, Lima - Perú | Teléfono (511) 626-2000
#       </p>
#       <p>
#        Todos los derechos reservados
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/js/bootstrap.js">
#   </script>
#   <script src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-content/themes/theme-facsociales/lib/matchHeight/jquery.matchHeight-min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
#         $('.home-destacados h2').matchHeight();
#         $('.home-cursos-modu h3').matchHeight();
#         $('.home-cursos-modu ul').matchHeight();
# 		$('.formato .carreras-lista .carreras-item-wrapper div.carreras-item div.carreras-item-cuerpo div.carreras-item-content').matchHeight();
#     });
# 	jQuery(document).ready(function($) {
# 		$('[href="http://facultad.pucp.edu.pe/ciencias-sociales/informacion-para-estudiantes/convenios/"]').attr('href','http://internacionalizacion.pucp.edu.pe/internacionalizacion-pucp/convenios-internacionales-pucp/').attr('target','_blank');
# 	});
#   </script>
#   <script id="wp-embed-js" src="https://facultad.pucp.edu.pe/ciencias-sociales/wp-includes/js/wp-embed.min.js?ver=555fd6d5b8897a90c60d6a1d9ce85b3f" type="text/javascript">
#   </script>
#  </body>
# </html>
# <!--
# Performance optimized by W3 Total Cache. Learn more: https://www.boldgrid.com/w3-total-cache/
#
# Caché de objetos 199/447 objetos usando disk
# Caché de base de datos 14/204 consultas en 0.087 segundos usando disk (Solicitud de ancho modification query)
#
# Served from: facultad.pucp.edu.pe @ 2022-03-10 01:48:34 by W3 Total Cache
# -->

# %%
cursos = soup.find_all('h2')
# Out:
# [<h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/seminario-interdisciplinario-temas-ciencias-sociales-2/?Carrera=antropologia">Seminario interdisciplinario de temas en ciencias sociales 2</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/seminario-interdisciplinario-temas-ciencias-sociales-1/?Carrera=antropologia">Seminario interdisciplinario de temas en ciencias sociales 1</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/curso-practico-etnografia-peruana/?Carrera=antropologia">Curso práctico de etnografía peruana</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-antropologia-1/?Carrera=antropologia">Temas en antropología 1</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/procesos-y-estrategias-de-toma-de-decisiones/?Carrera=antropologia">Procesos y estrategias de toma de decisiones</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/teologia-social/?Carrera=antropologia">Teología social</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/psicologia-social/?Carrera=antropologia">Psicología social</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/sociologia-y-antropologia-del-arte/?Carrera=antropologia">Sociología y antropología del arte</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/linguistica-andina/?Carrera=antropologia">Lingüística andina</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-en-antropologia-y-medio-ambiente/?Carrera=antropologia">Temas en antropología y medio ambiente</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/antropologia-economica/?Carrera=antropologia">Antropología Económica</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/antropologia-politica-1/?Carrera=antropologia">Antropología Política 1</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/simbolismo-y-ritual/?Carrera=antropologia">Simbolismo y Ritual</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/antropologia-del-desarrollo/?Carrera=antropologia">Antropología del Desarrollo</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/tecnicas-de-promocion/?Carrera=antropologia">Técnicas de Promoción</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-de-antropologia-3/?Carrera=antropologia">Temas en antropología 3</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-de-antropologia-4/?Carrera=antropologia">Temas en antropología 4</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-de-antropologia-5/?Carrera=antropologia">Temas en antropología 5</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-de-antropologia-6/?Carrera=antropologia">Temas en antropología 6</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/actividad-de-antropologia-1/?Carrera=antropologia">Actividad de Antropología</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/temas-en-teoria-antropologica/?Carrera=antropologia">Temas en teoría antropológica</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/trabajo-de-campo/?Carrera=antropologia">Trabajo de campo</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/educacion-cultura-y-desarrollo/?Carrera=antropologia">Educación, cultura y desarrollo</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/practica-de-campo-1/?Carrera=antropologia">Práctica de campo  1</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/practica-de-campo-2/?Carrera=antropologia">Práctica de campo 2</a></h2>, <h2><a href="https://facultad.pucp.edu.pe/ciencias-sociales/cursos/diseno-y-evaluacion-de ...

# %%
print(cursos[len(cursos) - 1].text)
# Out:
# Métodos y Técnicas de Investigación Antropológica 3

# %%
cursos2 = soup.find_all('div', {"class":["col-sm-12 listas-internas"]})

# %%
cursos2[0].find('p').text
# Out:
# 'Curso interdisciplinario de contenido variable sobre temas analizados y discutidos por las Ciencias Sociales. Se ofrece\xa0a los y las estudiantes\xa0 perspectivas analíticas de las distintas especialidades de las ciencias sociales a modo de conocer las distintas aproximaciones y debates en torno a un mismo fenómeno…\n'

# %%
cursos2[0].find('h2').text
# Out:
# 'Seminario interdisciplinario de temas en ciencias sociales 2'

# %%
cursos2[len(cursos2) - 1].find('p').text
# Out:
# 'Métodos de análisis de datos. El problema de la representatividad y la generalización de datos cualitativos. Los métodos de análisis cualitativo (análisis de contenido, análisis estructural, etc.) Codificación de datos. Análisis computarizado de datos.'

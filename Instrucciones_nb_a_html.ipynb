# %% [markdown]
# <a href="https://colab.research.google.com/github/ccsuehara/python_para_las_ccss/blob/main/Instrucciones_nb_a_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instrucciones para convertir un notebook a html
# ## Instrucciones aplicables a google colab.
#
# 1. Sube tu notebook a la carpeta izquierda de content, como lo hemos venido haciendo cuando usamos datos externos.
# - **importante: Corre todo el notebook, el código tiene que estar ejecutado**
#
# 2. Corre la siguiente línea (basta con cambiar el nombre del archivo):

# %%
# !jupyter nbconvert --to html --no-input "/content/2.Visualizacion_de_datos_2.ipynb"

# %% [markdown]
# 3. Se creará un archivo html. Descárgalo.
# 4. Cámbiale de nombre a `index.html`
# 5. Súbelo a tu repo en la rama main.
# 6. En la configuración de tu repositorio, ve a "Pages". En source, selecciona "deploy from a branch" y selecciona main + root (Checkea la imagen de abajo).
# 7. Espera un par de minutos y listo! Eso es todo. La URL será https://username.github.io/nombre-repo/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
